# %% [markdown]
# # NASCAR Race Winner Prediction: Monte Carlo Simulation
# ## Notebook 1: Data Preprocessing

# %%
import pandas as pd
from data_pulling import *
import sys
sys.dont_write_bytecode = True
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# For this notebook, I will be using web crawling to extract data.

# %%
cup_roster = pd.read_csv("https://raw.githubusercontent.com/jake-lukasik/NASCAR-Race-Predictions/refs/heads/main/Data/Master-Data/2025-cup-series-full-timers.txt")

# %% [markdown]
# ### Race 4: Watkins Glen (RC) 08/11/2025

# %% [markdown]
# Step 1: Pulling watkins_glen stats from driveraverages.com, I left a ton of comments so this is easily understandable

# %%
watkins_glen_stats = pull_data_from_driver_averages(url="https://www.driveraverages.com/nascar/track_avg.php?trk_id=22",
                                            driver_in_first="Shane van Gisbergen",
                                            driver_in_fourth="Christopher Bell")
watkins_glen_stats.head()
# Out:
# Found 6 tables.
#                 Driver  Avg Finish  Races  Wins  Top 5's  Top 10's  Top 20's  \
# 0  Shane van Gisbergen         2.0      1     0        1         1         1
# 1       Carson Hocevar         3.0      1     0        1         1         1
# 2           Zane Smith         5.0      1     0        1         1         1
# 3     Christopher Bell         8.0      4     0        1         3         4
# 4        Chase Elliott        10.6      8     2        4         4         7
#
#    Laps Led  Avg Start  Best Finish  Low Finish  DNF  Avg Rating
# 0         1        3.0            2           2    0       123.9
# 1         1       29.0            3           3    0       103.6
# 2         0       19.0            5           5    0        93.7
# 3         0       17.3            3          14    0        92.9
# 4       170        8.1            1          32    0       107.6

# %%
season_stats = pull_season_stats(driver_in_first="William Byron")
season_stats.head()
# Out:
#              Driver  szn_Avg Finish  szn_Races  szn_Wins  szn_Top 5's  \
# 0     William Byron            14.2         23         2            8
# 1     Chase Elliott            10.3         23         1            7
# 2       Kyle Larson            13.5         23         3           11
# 3      Denny Hamlin            13.0         22         4           11
# 4  Christopher Bell            12.6         23         3            8
#
#    szn_Laps Led  szn_Avg Rating
# 0           910           100.5
# 1           385            89.9
# 2           873            92.9
# 3           555            91.3
# 4           221            89.1

# %%
rd_course_stats = pull_road_course_stats(url="https://www.driveraverages.com/nascar/tracktype_avg.php?trktype_id=4",
                                         driver_in_first="Chase Elliott")
rd_course_stats = rd_course_stats[rd_course_stats['Driver'].isin(cup_roster['Driver'])].reset_index(drop=True)
display(rd_course_stats)
# Out:
#                   Driver  Avg Finish  Races  Wins  Top 5's  Top 10's  \
# 0          Chase Elliott         8.9     39     7       22        26
# 1    Shane van Gisbergen         8.9     10     4        5         8
# 2          Tyler Reddick        12.0     30     3       10        19
# 3         Chris Buescher        13.1     41     1        6        17
# 4       Christopher Bell        13.7     30     3       10        16
# 5            Joey Logano        14.7     54     1       12        25
# 6             Kyle Busch        14.7     62     4       22        34
# 7            Alex Bowman        14.9     39     1        8        17
# 8               Ty Gibbs        15.3     18     0        5         8
# 9            Ryan Blaney        15.5     40     1        5        16
# 10           Kyle Larson        15.6     42     6       11        16
# 11     A.J. Allmendinger        15.9     47     3        9        23
# 12         William Byron        16.1     36     2        6        15
# 13        Austin Cindric        16.3     24     0        3         9
# 14          Denny Hamlin        16.7     59     1       15        21
# 15         Ross Chastain        17.1     33     1        6        13
# 16       Brad Keselowski        17.6     52     0        7        11
# 17         Chase Briscoe        19.0     28     0        1         8
# 18      Michael McDowell        19.7     51     1        6        15
# 19           Cole Custer        19.8     20     0        0         3
# 20            Erik Jones        20.1     38     0        3         9
# 21        Todd Gilliland        20.5     21     0        1         5
# 22         Daniel Suarez        20.7     38     1        6         6
# 23        Carson Hocevar        21.3      9     0        1         1
# 24           Ryan Preece        21.7     27     0        0         3
# 25          Riley Herbst        22.0      4     0        0         0
# 26            Zane Smith        22.3     11     0        1         1
# 27         Bubba Wallace        22.6     36     0        1         3
# 28   Ricky Stenhouse Jr.        22.7     46     0        0         2
# 29          Justin Haley        22.7     28     0        2         3
# 30         Austin Dillon        23.5     43     0        0         2
# 31          Noah Gragson        24.1     12     0        0         1
# 32             Ty Dillon        25.2     29     0        0         0
# 33  John Hunter Nemechek        25.6     11     0        0         1
# 34            Josh Berry        27.7      9     0        0         0
# 35             Cody Ware        31.5     19     0        0         0
#
#     Top 20's  Laps Led  Avg Start  Best Finish  Low Finish  DNF
# 0         34       489        9.4            1          37    1
# 1          9       247        4.1            1          40    1
# 2         24       217        7.6            1          38    1
# 3         37        62       18.3            1          37    0
# 4         21       125       13.4            1          38    4
# 5         37       147       12.1            1          37    2
# 6         43       472       11.9            1          40    4
# 7         30        19       16.4            1          38    1
# 8         12        46       10.9            2          37    1
# 9         29        74       16.2            1          38    2
# 10        28       308        7.8            1          39    2
# 11        33       231       11.8            1          38    5
# 12        24       260       13.3            1          40    5
# 13        15        20       16.1            2          38    1
# 14        40       244       14.1            1          38    6
# 15        18       104       17.3            1          39    2
# 16        37       191       17.7            2          37    4
# 17        15        45       18.1            2          36    3
# 18        28       136       16.8            1          42    9
# 19        10         7       19.8            8          36    2
# 20        20         3       24.9            3          40    3
# 21        10         9       24.2            4          38    2
# 22        18        85       13.0            1          37    3
# 23         4         1       16.2            3          35    1
# 24        13        17       23.6            7          40    4
# 25         2         0       23.8           17          29    0
# 26         6         3       24.7            5          35    1
# 27        16         4       20.9            5          39    7
# 28        24         3       26.3            6          38    8
# 29        11        23       24.4            2          40    3
# 30        19         8       20.8           10          39    7
# 31         4         0       24.8            8          37    1
# 32         9         5       30.8           15          39    3
# 33         2         0       26.9            6          36    2
# 34         1         0       29.8           13          36    2
# 35         0         0       34.3           24          40    6

# %%
watkins_glen_stats = watkins_glen_stats[watkins_glen_stats['Driver'].isin(cup_roster['Driver'])]
watkins_glen_stats.head()
# Out:
#                 Driver  Avg Finish  Races  Wins  Top 5's  Top 10's  Top 20's  \
# 0  Shane van Gisbergen         2.0      1     0        1         1         1
# 1       Carson Hocevar         3.0      1     0        1         1         1
# 2           Zane Smith         5.0      1     0        1         1         1
# 3     Christopher Bell         8.0      4     0        1         3         4
# 4        Chase Elliott        10.6      8     2        4         4         7
#
#    Laps Led  Avg Start  Best Finish  Low Finish  DNF  Avg Rating
# 0         1        3.0            2           2    0       123.9
# 1         1       29.0            3           3    0       103.6
# 2         0       19.0            5           5    0        93.7
# 3         0       17.3            3          14    0        92.9
# 4       170        8.1            1          32    0       107.6

# %%
watkins_glen_stats = watkins_glen_stats.drop(columns=["Top 20's", "Avg Start", "Best Finish", "Low Finish"])
watkins_glen_stats.head()
# Out:
#                 Driver  Avg Finish  Races  Wins  Top 5's  Top 10's  Laps Led  \
# 0  Shane van Gisbergen         2.0      1     0        1         1         1
# 1       Carson Hocevar         3.0      1     0        1         1         1
# 2           Zane Smith         5.0      1     0        1         1         0
# 3     Christopher Bell         8.0      4     0        1         3         0
# 4        Chase Elliott        10.6      8     2        4         4       170
#
#    DNF  Avg Rating
# 0    0       123.9
# 1    0       103.6
# 2    0        93.7
# 3    0        92.9
# 4    0       107.6

# %% [markdown]
# ## New for Road Courses: Build out this 'Road Course Weight' Feature

# %%
performance_metrics = rd_course_stats[['Avg Finish', 'Wins', "Top 5's", "Top 10's", 'Laps Led', 'DNF']].copy()
# reverse 'Avg Finish' and 'DNF' since lower is better
performance_metrics['Avg Finish'] = -performance_metrics['Avg Finish']
performance_metrics['DNF'] = -performance_metrics['DNF']

# normalize all columns between 0 and 1
scaler = MinMaxScaler()
normalized = scaler.fit_transform(performance_metrics)
normalized_df = pd.DataFrame(normalized, columns=performance_metrics.columns)

# Add driver names back
normalized_df['Driver'] = rd_course_stats['Driver']
normalized_df.head()
# Out:
#    Avg Finish      Wins   Top 5's  Top 10's  Laps Led       DNF  \
# 0    1.000000  1.000000  1.000000  0.764706  1.000000  0.888889
# 1    1.000000  0.571429  0.227273  0.235294  0.505112  0.888889
# 2    0.862832  0.428571  0.454545  0.558824  0.443763  0.888889
# 3    0.814159  0.142857  0.272727  0.500000  0.126789  1.000000
# 4    0.787611  0.428571  0.454545  0.470588  0.255624  0.555556
#
#                 Driver
# 0        Chase Elliott
# 1  Shane van Gisbergen
# 2        Tyler Reddick
# 3       Chris Buescher
# 4     Christopher Bell

# %%
weights = {
    'Avg Finish': 0.4,
    'Wins': 0.4,
    "Top 5's": 0.05,
    'Laps Led': 0.05,
    'DNF': 0.1
}

# weighted score
normalized_df['RoadCourseMultiplier'] = sum(
    normalized_df[col] * weight for col, weight in weights.items()
)

normalized_df.head()
# Out:
#    Avg Finish      Wins   Top 5's  Top 10's  Laps Led       DNF  \
# 0    1.000000  1.000000  1.000000  0.764706  1.000000  0.888889
# 1    1.000000  0.571429  0.227273  0.235294  0.505112  0.888889
# 2    0.862832  0.428571  0.454545  0.558824  0.443763  0.888889
# 3    0.814159  0.142857  0.272727  0.500000  0.126789  1.000000
# 4    0.787611  0.428571  0.454545  0.470588  0.255624  0.555556
#
#                 Driver  RoadCourseMultiplier
# 0        Chase Elliott              0.988889
# 1  Shane van Gisbergen              0.754080
# 2        Tyler Reddick              0.650366
# 3       Chris Buescher              0.502782
# 4     Christopher Bell              0.577537

# %% [markdown]
# Now we can begin feature engineering to prepare the data for a Monte Carlo simulated model:

# %%
# Helper functions, we will apply these later:

# estimate_std, since standard deviation of finishes is not easily available,
# we instead estimate it based off of drivers average finish (a better average
# finish gives us a clue that that driver is more consistent)
def estimate_std(avg_finish):
    if avg_finish <= 12:
        return 2.5
    elif avg_finish <= 18:
        return 3.5
    else:
        return 4.5
    
# calculate the probability of a dnf, using DNF count along with race count, includes
# some manual tweaks to ensure this is a valuable and realistic measure
def dnf_prob(dnf_count, race_count):
    dnf_probability = dnf_count / race_count

    if dnf_probability == 0:
        if race_count >= 5:
            return 0.03  
        else:
            return 0.15 
    elif dnf_probability == 1:
        return 0.4  # cap max failure
    else:
        return min(dnf_probability, 0.35)  # avoid extreme dnf probabilites
    
# simple ratio of laps led per race
def laps_led_per_race(laps_led, races):
    return laps_led/races

# %%
watkins_glen_stats_engineered = pd.merge(watkins_glen_stats, season_stats, on='Driver', how='inner')
watkins_glen_stats_engineered.head()
# Out:
#                 Driver  Avg Finish  Races  Wins  Top 5's  Top 10's  Laps Led  \
# 0  Shane van Gisbergen         2.0      1     0        1         1         1
# 1       Carson Hocevar         3.0      1     0        1         1         1
# 2           Zane Smith         5.0      1     0        1         1         0
# 3     Christopher Bell         8.0      4     0        1         3         0
# 4        Chase Elliott        10.6      8     2        4         4       170
#
#    DNF  Avg Rating  szn_Avg Finish  szn_Races  szn_Wins  szn_Top 5's  \
# 0    0       123.9            22.5         23         3            3
# 1    0       103.6            22.3         23         0            2
# 2    0        93.7            21.0         23         0            0
# 3    0        92.9            12.6         23         3            8
# 4    0       107.6            10.3         23         1            7
#
#    szn_Laps Led  szn_Avg Rating
# 0           208            60.5
# 1            80            74.1
# 2            15            63.5
# 3           221            89.1
# 4           385            89.9

# %%
watkins_glen_stats_engineered['DNF_Prob'] = watkins_glen_stats_engineered.apply(lambda row: dnf_prob(row['DNF'], row['Races']), axis=1)
watkins_glen_stats_engineered.head()
# Out:
#                 Driver  Avg Finish  Races  Wins  Top 5's  Top 10's  Laps Led  \
# 0  Shane van Gisbergen         2.0      1     0        1         1         1
# 1       Carson Hocevar         3.0      1     0        1         1         1
# 2           Zane Smith         5.0      1     0        1         1         0
# 3     Christopher Bell         8.0      4     0        1         3         0
# 4        Chase Elliott        10.6      8     2        4         4       170
#
#    DNF  Avg Rating  szn_Avg Finish  szn_Races  szn_Wins  szn_Top 5's  \
# 0    0       123.9            22.5         23         3            3
# 1    0       103.6            22.3         23         0            2
# 2    0        93.7            21.0         23         0            0
# 3    0        92.9            12.6         23         3            8
# 4    0       107.6            10.3         23         1            7
#
#    szn_Laps Led  szn_Avg Rating  DNF_Prob
# 0           208            60.5      0.15
# 1            80            74.1      0.15
# 2            15            63.5      0.15
# 3           221            89.1      0.15
# 4           385            89.9      0.03

# %%
watkins_glen_stats_engineered['track_Laps Led Per Race'] = watkins_glen_stats_engineered.apply(lambda row: laps_led_per_race(row['Laps Led'], row['Races']), axis=1)
watkins_glen_stats_engineered['szn_Laps Led Per Race'] = watkins_glen_stats_engineered.apply(lambda row: laps_led_per_race(row['szn_Laps Led'], row['szn_Races']), axis=1)

# %%
watkins_glen_stats_engineered['Std Dev'] = watkins_glen_stats_engineered.apply(lambda row: estimate_std(row['Avg Finish']), axis=1)
watkins_glen_stats_engineered.head()
# Out:
#                 Driver  Avg Finish  Races  Wins  Top 5's  Top 10's  Laps Led  \
# 0  Shane van Gisbergen         2.0      1     0        1         1         1
# 1       Carson Hocevar         3.0      1     0        1         1         1
# 2           Zane Smith         5.0      1     0        1         1         0
# 3     Christopher Bell         8.0      4     0        1         3         0
# 4        Chase Elliott        10.6      8     2        4         4       170
#
#    DNF  Avg Rating  szn_Avg Finish  szn_Races  szn_Wins  szn_Top 5's  \
# 0    0       123.9            22.5         23         3            3
# 1    0       103.6            22.3         23         0            2
# 2    0        93.7            21.0         23         0            0
# 3    0        92.9            12.6         23         3            8
# 4    0       107.6            10.3         23         1            7
#
#    szn_Laps Led  szn_Avg Rating  DNF_Prob  track_Laps Led Per Race  \
# 0           208            60.5      0.15                     1.00
# 1            80            74.1      0.15                     1.00
# 2            15            63.5      0.15                     0.00
# 3           221            89.1      0.15                     0.00
# 4           385            89.9      0.03                    21.25
#
#    szn_Laps Led Per Race  Std Dev
# 0               9.043478      2.5
# 1               3.478261      2.5
# 2               0.652174      2.5
# 3               9.608696      2.5
# 4              16.739130      2.5

# %%
watkins_glen_stats_engineered = watkins_glen_stats_engineered.drop(columns=["Races", "Top 10's", "Laps Led", "szn_Races", "szn_Laps Led"])
watkins_glen_stats_engineered.head()
# Out:
#                 Driver  Avg Finish  Wins  Top 5's  DNF  Avg Rating  \
# 0  Shane van Gisbergen         2.0     0        1    0       123.9
# 1       Carson Hocevar         3.0     0        1    0       103.6
# 2           Zane Smith         5.0     0        1    0        93.7
# 3     Christopher Bell         8.0     0        1    0        92.9
# 4        Chase Elliott        10.6     2        4    0       107.6
#
#    szn_Avg Finish  szn_Wins  szn_Top 5's  szn_Avg Rating  DNF_Prob  \
# 0            22.5         3            3            60.5      0.15
# 1            22.3         0            2            74.1      0.15
# 2            21.0         0            0            63.5      0.15
# 3            12.6         3            8            89.1      0.15
# 4            10.3         1            7            89.9      0.03
#
#    track_Laps Led Per Race  szn_Laps Led Per Race  Std Dev
# 0                     1.00               9.043478      2.5
# 1                     1.00               3.478261      2.5
# 2                     0.00               0.652174      2.5
# 3                     0.00               9.608696      2.5
# 4                    21.25              16.739130      2.5

# %%
watkins_glen_stats_engineered = watkins_glen_stats_engineered.merge(normalized_df[['Driver', 'RoadCourseMultiplier']], on='Driver', how='left')
watkins_glen_stats_engineered.head()
# Out:
#                 Driver  Avg Finish  Wins  Top 5's  DNF  Avg Rating  \
# 0  Shane van Gisbergen         2.0     0        1    0       123.9
# 1       Carson Hocevar         3.0     0        1    0       103.6
# 2           Zane Smith         5.0     0        1    0        93.7
# 3     Christopher Bell         8.0     0        1    0        92.9
# 4        Chase Elliott        10.6     2        4    0       107.6
#
#    szn_Avg Finish  szn_Wins  szn_Top 5's  szn_Avg Rating  DNF_Prob  \
# 0            22.5         3            3            60.5      0.15
# 1            22.3         0            2            74.1      0.15
# 2            21.0         0            0            63.5      0.15
# 3            12.6         3            8            89.1      0.15
# 4            10.3         1            7            89.9      0.03
#
#    track_Laps Led Per Race  szn_Laps Led Per Race  Std Dev  \
# 0                     1.00               9.043478      2.5
# 1                     1.00               3.478261      2.5
# 2                     0.00               0.652174      2.5
# 3                     0.00               9.608696      2.5
# 4                    21.25              16.739130      2.5
#
#    RoadCourseMultiplier
# 0              0.754080
# 1              0.271795
# 2              0.254300
# 3              0.577537
# 4              0.988889

# %%
# Input files able to be read from GitHub: Don't feel like doing the API request stuff to write this out as well,
# This is all behind the scenes anyways :)
#watkins_glen_stats_engineered.to_csv("C:/Users/jakel/OneDrive/Desktop/GitHub/NASCAR-Race-Predictions/Data/Watkins-Glen-2025/watkins-glen-sim-ready-data.csv")
