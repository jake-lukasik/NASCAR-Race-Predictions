# %% [markdown]
# # NASCAR Race Winner Prediction: Monte Carlo Simulation
# ## Notebook 1: Data Preprocessing

# %%
import pandas as pd

# %% [markdown]
# ### Race 1: Pocono 06/22/2025

# %%
pocono_stats = pd.read_csv("https://raw.githubusercontent.com/jake-lukasik/NASCAR-Race-Predictions/refs/heads/main/Data/Pocono-2025/driver-stats-pocono.txt")
cup_roster = pd.read_csv("https://raw.githubusercontent.com/jake-lukasik/NASCAR-Race-Predictions/refs/heads/main/Data/Master-Data/2025-cup-series-full-timers.txt")
season_stats = pd.read_csv("https://raw.githubusercontent.com/jake-lukasik/NASCAR-Race-Predictions/refs/heads/main/Data/Master-Data/season-stats.txt")

# %%
season_stats = season_stats.drop(columns=['NASCAR Points', "Top 10's"])

season_stats = season_stats.rename(
    columns={col: f"szn_{col}" for col in season_stats.columns if col != "Driver"}
)

season_stats
# Out:
#                   Driver  szn_Avg Finish  szn_Races  szn_Wins  szn_Top 5's  \
# 0          William Byron            10.4         16         1            7
# 1            Kyle Larson            12.8         16         3            9
# 2       Christopher Bell            10.6         16         3            7
# 3          Chase Elliott            11.2         16         0            4
# 4           Denny Hamlin            13.5         15         3            7
# 5          Tyler Reddick            14.5         16         0            3
# 6            Ryan Blaney            17.4         16         1            6
# 7          Ross Chastain            12.6         16         1            3
# 8            Joey Logano            16.9         16         1            2
# 9          Bubba Wallace            18.3         16         0            3
# 10         Chase Briscoe            14.5         16         0            5
# 11           Alex Bowman            19.3         16         0            3
# 12        Chris Buescher            14.6         16         0            2
# 13           Ryan Preece            18.6         16         0            1
# 14        Austin Cindric            19.1         16         1            1
# 15      Michael McDowell            18.3         16         0            1
# 16     A.J. Allmendinger            20.3         16         0            1
# 17            Kyle Busch            18.1         16         0            1
# 18            Josh Berry            20.9         16         1            2
# 19        Carson Hocevar            22.8         16         0            2
# 20   Ricky Stenhouse Jr.            19.1         16         0            1
# 21            Erik Jones            19.6         16         0            1
# 22  John Hunter Nemechek            19.5         16         0            1
# 23              Ty Gibbs            19.8         16         0            2
# 24            Zane Smith            20.0         16         0            0
# 25        Todd Gilliland            20.1         16         0            0
# 26         Austin Dillon            19.8         16         0            0
# 27         Daniel Suarez            21.0         16         0            1
# 28          Justin Haley            22.5         16         0            0
# 29   Shane van Gisbergen            23.8         16         1            1
# 30             Ty Dillon            23.1         16         0            0
# 31       Brad Keselowski            24.3         16         0            1
# 32          Noah Gragson            23.2         16         0            1
# 33           Cole Custer            24.4         16         0            0
# 34          Riley Herbst            25.1         16         0            0
# 35             Cody Ware            30.3         16         0            0
#
#     szn_Laps Led  szn_Avg Rating
# 0            769           106.7
# 1            851            96.0
# 2            153            94.2
# 3             95            85.5
# 4            455            94.3
# 5             94            90.6
# 6            346            90.6
# 7             58            80.3
# 8            302            84.5
# 9            103            82.4
# 10            92            80.8
# 11           110            78.1
# 12            16            79.2
# 13            53            78.5
# 14           239            80.0
# 15            43            66.8
# 16             2            66.7
# 17            62            73.6
# 18           169            76.8
# 19            70            75.1
# 20             0            57.5
# 21             1            63.7
# 22             2            57.1
# 23            65            69.0
# 24            10            64.2
# 25            11            58.5
# 26             8            60.9
# 27            14            62.4
# 28             0            55.0
# 29            85            54.4
# 30             8            51.3
# 31             8            62.9
# 32             2            58.2
# 33             2            48.2
# 34             0            46.7
# 35             2            33.3

# %%
pocono_stats = pocono_stats[pocono_stats['Driver'].isin(cup_roster['Driver'])]
pocono_stats
# Out:
#     Rank                Driver  Avg Finish  Races  Wins  Top 5's  Top 10's  \
# 0      1         William Byron         9.4     11     0        3         6
# 1      2       Brad Keselowski        10.8     27     1       11        16
# 2      3          Denny Hamlin        11.3     35     7       16        23
# 3      4           Kyle Larson        11.6     17     0        5         9
# 5      6           Ryan Blaney        13.4     15     2        3         7
# 6      7         Chase Elliott        13.5     15     1        4        10
# 7      8            Erik Jones        13.5     13     0        5         8
# 8      9         Tyler Reddick        13.6      7     0        2         4
# 11    12              Ty Gibbs        16.0      3     0        1         1
# 12    13            Kyle Busch        16.3     37     4       11        18
# 13    14      Christopher Bell        16.3      7     0        2         3
# 14    15         Daniel Suarez        16.7     13     0        2         4
# 15    16        Carson Hocevar        17.0      1     0        0         0
# 16    17           Alex Bowman        17.3     15     1        3         5
# 17    18           Joey Logano        17.5     29     1        5        11
# 19    20         Austin Dillon        19.1     19     0        0         1
# 20    21         Bubba Wallace        19.2     12     0        1         3
# 21    22        Chris Buescher        20.0     15     1        1         2
# 22    23            Josh Berry        20.0      1     0        0         0
# 24    25         Chase Briscoe        20.8      5     0        0         0
# 25    26   Ricky Stenhouse Jr.        22.3     21     0        0         1
# 27    28     A.J. Allmendinger        22.5     24     0        0         2
# 28    29             Ty Dillon        23.0     12     0        0         0
# 29    30  John Hunter Nemechek        23.7      3     0        0         0
# 31    32        Austin Cindric        24.0      3     0        0         0
# 32    33           Ryan Preece        24.6      8     0        0         1
# 33    34        Todd Gilliland        24.7      3     0        0         0
# 34    35      Michael McDowell        25.8     22     0        0         2
# 35    36          Justin Haley        25.8      4     0        0         0
# 37    38          Noah Gragson        27.7      3     0        0         0
# 38    39         Ross Chastain        28.6      9     0        0         0
# 39    40             Cody Ware        28.8      5     0        0         0
# 40    41            Zane Smith        29.0      1     0        0         0
#
#     Top 20's  Laps Led  Avg Start  Best Finish  Low Finish  DNF  Avg Rating
# 0         11       130       13.6            3          18    0        96.7
# 1         23       247       12.0            1          38    1        94.4
# 2         28       858        7.5            1          43    3       108.7
# 3         14       158       12.9            2          33    0        95.8
# 5         11        95       13.6            1          33    1        89.6
# 6         11        67       14.9            1          38    1        93.9
# 7          9        56       18.6            2          38    1        89.3
# 8          5        15       14.4            2          35    0        81.9
# 11         2        25        7.3            5          27    1        78.6
# 12        22       585       11.8            1          43    7        95.6
# 13         5        17       13.6            4          39    1        83.3
# 14         8        39       14.3            2          36    1        72.6
# 15         1         0       15.0           17          17    0        64.3
# 16         8        34       19.7            1          31    0        74.7
# 17        17       328       11.4            1          40    1        87.3
# 19        13        10       16.1           10          37    3        69.0
# 20         6        11       19.9            5          38    2        65.8
# 21        10        40       19.4            1          37    1        67.3
# 22         1         8        5.0           20          20    0        68.7
# 24         2         0       24.4           15          29    0        58.0
# 25        12        14       18.7            7          42    4        62.8
# 27        10         5       21.7            7          39    4        65.3
# 28         3         3       27.3           17          29    0        51.0
# 29         1         0       25.3           19          28    1        51.1
# 31         1         0       16.3           18          31    0        48.4
# 32         2         0       25.5            8          37    2        53.9
# 33         1         0       32.7           15          34    1        42.1
# 34         8        14       25.4            6          43    7        52.2
# 35         0         0       29.3           21          33    1        46.6
# 37         0         0       26.3           22          37    1        38.8
# 38         1        26       24.7           13          36    2        53.9
# 39         0         0       33.8           25          39    2        36.0
# 40         0         0        9.0           29          29    1        63.2

# %% [markdown]
# #### Important note:
#
# **Missing Cole Custer, SVG, and Riley Herbst.** Due to the nature of this Monte Carlo simulation, and how we depend mainly on track specific statistics, these drivers will not be included in the full simulation.

# %%
pocono_stats.drop(columns=["Rank", "Top 20's", "Avg Start", "Best Finish", "Low Finish"], inplace=True)
pocono_stats
# Out:
#                   Driver  Avg Finish  Races  Wins  Top 5's  Top 10's  \
# 0          William Byron         9.4     11     0        3         6
# 1        Brad Keselowski        10.8     27     1       11        16
# 2           Denny Hamlin        11.3     35     7       16        23
# 3            Kyle Larson        11.6     17     0        5         9
# 5            Ryan Blaney        13.4     15     2        3         7
# 6          Chase Elliott        13.5     15     1        4        10
# 7             Erik Jones        13.5     13     0        5         8
# 8          Tyler Reddick        13.6      7     0        2         4
# 11              Ty Gibbs        16.0      3     0        1         1
# 12            Kyle Busch        16.3     37     4       11        18
# 13      Christopher Bell        16.3      7     0        2         3
# 14         Daniel Suarez        16.7     13     0        2         4
# 15        Carson Hocevar        17.0      1     0        0         0
# 16           Alex Bowman        17.3     15     1        3         5
# 17           Joey Logano        17.5     29     1        5        11
# 19         Austin Dillon        19.1     19     0        0         1
# 20         Bubba Wallace        19.2     12     0        1         3
# 21        Chris Buescher        20.0     15     1        1         2
# 22            Josh Berry        20.0      1     0        0         0
# 24         Chase Briscoe        20.8      5     0        0         0
# 25   Ricky Stenhouse Jr.        22.3     21     0        0         1
# 27     A.J. Allmendinger        22.5     24     0        0         2
# 28             Ty Dillon        23.0     12     0        0         0
# 29  John Hunter Nemechek        23.7      3     0        0         0
# 31        Austin Cindric        24.0      3     0        0         0
# 32           Ryan Preece        24.6      8     0        0         1
# 33        Todd Gilliland        24.7      3     0        0         0
# 34      Michael McDowell        25.8     22     0        0         2
# 35          Justin Haley        25.8      4     0        0         0
# 37          Noah Gragson        27.7      3     0        0         0
# 38         Ross Chastain        28.6      9     0        0         0
# 39             Cody Ware        28.8      5     0        0         0
# 40            Zane Smith        29.0      1     0        0         0
#
#     Laps Led  DNF  Avg Rating
# 0        130    0        96.7
# 1        247    1        94.4
# 2        858    3       108.7
# 3        158    0        95.8
# 5         95    1        89.6
# 6         67    1        93.9
# 7         56    1        89.3
# 8         15    0        81.9
# 11        25    1        78.6
# 12       585    7        95.6
# 13        17    1        83.3
# 14        39    1        72.6
# 15         0    0        64.3
# 16        34    0        74.7
# 17       328    1        87.3
# 19        10    3        69.0
# 20        11    2        65.8
# 21        40    1        67.3
# 22         8    0        68.7
# 24         0    0        58.0
# 25        14    4        62.8
# 27         5    4        65.3
# 28         3    0        51.0
# 29         0    1        51.1
# 31         0    0        48.4
# 32         0    2        53.9
# 33         0    1        42.1
# 34        14    7        52.2
# 35         0    1        46.6
# 37         0    1        38.8
# 38        26    2        53.9
# 39         0    2        36.0
# 40         0    1        63.2

# %% [markdown]
# Now we can begin feature engineering to prepare the data for a Monte Carlo simulated model:

# %%
# Helper functions, we will apply these later:

# estimate_std, since standard deviation of finishes is not easily available,
# we instead estimate it based off of drivers average finish (a better average
# finish gives us a clue that that driver is more consistent)
def estimate_std(avg_finish):
    if avg_finish <= 12:
        return 2.5
    elif avg_finish <= 18:
        return 3.5
    else:
        return 4.5
    
# calculate the probability of a dnf, using DNF count along with race count, includes
# some manual tweaks to ensure this is a valuable and realistic measure
def dnf_prob(dnf_count, race_count):
    dnf_probability = dnf_count / race_count

    if dnf_probability == 0:
        if race_count >= 5:
            return 0.03  
        else:
            return 0.15 
    elif dnf_probability == 1:
        return 0.4  # cap max failure
    else:
        return min(dnf_probability, 0.35)  # avoid extreme dnf probabilites
    
# simple ratio of laps led per race
def laps_led_per_race(laps_led, races):
    return laps_led/races

# %%
pocono_stats_engineered = pd.merge(pocono_stats, season_stats, on='Driver', how='inner')
pocono_stats_engineered.head()
# Out:
#             Driver  Avg Finish  Races  Wins  Top 5's  Top 10's  Laps Led  DNF  \
# 0    William Byron         9.4     11     0        3         6       130    0
# 1  Brad Keselowski        10.8     27     1       11        16       247    1
# 2     Denny Hamlin        11.3     35     7       16        23       858    3
# 3      Kyle Larson        11.6     17     0        5         9       158    0
# 4      Ryan Blaney        13.4     15     2        3         7        95    1
#
#    Avg Rating  szn_Avg Finish  szn_Races  szn_Wins  szn_Top 5's  szn_Laps Led  \
# 0        96.7            10.4         16         1            7           769
# 1        94.4            24.3         16         0            1             8
# 2       108.7            13.5         15         3            7           455
# 3        95.8            12.8         16         3            9           851
# 4        89.6            17.4         16         1            6           346
#
#    szn_Avg Rating
# 0           106.7
# 1            62.9
# 2            94.3
# 3            96.0
# 4            90.6

# %%
pocono_stats_engineered['DNF_Prob'] = pocono_stats_engineered.apply(lambda row: dnf_prob(row['DNF'], row['Races']), axis=1)
pocono_stats_engineered.head()
# Out:
#             Driver  Avg Finish  Races  Wins  Top 5's  Top 10's  Laps Led  DNF  \
# 0    William Byron         9.4     11     0        3         6       130    0
# 1  Brad Keselowski        10.8     27     1       11        16       247    1
# 2     Denny Hamlin        11.3     35     7       16        23       858    3
# 3      Kyle Larson        11.6     17     0        5         9       158    0
# 4      Ryan Blaney        13.4     15     2        3         7        95    1
#
#    Avg Rating  szn_Avg Finish  szn_Races  szn_Wins  szn_Top 5's  szn_Laps Led  \
# 0        96.7            10.4         16         1            7           769
# 1        94.4            24.3         16         0            1             8
# 2       108.7            13.5         15         3            7           455
# 3        95.8            12.8         16         3            9           851
# 4        89.6            17.4         16         1            6           346
#
#    szn_Avg Rating  DNF_Prob
# 0           106.7  0.030000
# 1            62.9  0.037037
# 2            94.3  0.085714
# 3            96.0  0.030000
# 4            90.6  0.066667

# %%
pocono_stats_engineered['track_Laps Led Per Race'] = pocono_stats_engineered.apply(lambda row: laps_led_per_race(row['Laps Led'], row['Races']), axis=1)
pocono_stats_engineered['szn_Laps Led Per Race'] = pocono_stats_engineered.apply(lambda row: laps_led_per_race(row['szn_Laps Led'], row['szn_Races']), axis=1)

# %%
pocono_stats_engineered['Std Dev'] = pocono_stats_engineered.apply(lambda row: estimate_std(row['Avg Finish']), axis=1)
pocono_stats_engineered.head()
# Out:
#             Driver  Avg Finish  Races  Wins  Top 5's  Top 10's  Laps Led  DNF  \
# 0    William Byron         9.4     11     0        3         6       130    0
# 1  Brad Keselowski        10.8     27     1       11        16       247    1
# 2     Denny Hamlin        11.3     35     7       16        23       858    3
# 3      Kyle Larson        11.6     17     0        5         9       158    0
# 4      Ryan Blaney        13.4     15     2        3         7        95    1
#
#    Avg Rating  szn_Avg Finish  szn_Races  szn_Wins  szn_Top 5's  szn_Laps Led  \
# 0        96.7            10.4         16         1            7           769
# 1        94.4            24.3         16         0            1             8
# 2       108.7            13.5         15         3            7           455
# 3        95.8            12.8         16         3            9           851
# 4        89.6            17.4         16         1            6           346
#
#    szn_Avg Rating  DNF_Prob  track_Laps Led Per Race  szn_Laps Led Per Race  \
# 0           106.7  0.030000                11.818182              48.062500
# 1            62.9  0.037037                 9.148148               0.500000
# 2            94.3  0.085714                24.514286              30.333333
# 3            96.0  0.030000                 9.294118              53.187500
# 4            90.6  0.066667                 6.333333              21.625000
#
#    Std Dev
# 0      2.5
# 1      2.5
# 2      2.5
# 3      2.5
# 4      3.5

# %%
pocono_stats_engineered.drop(columns=["Races", "Top 10's", "Laps Led", "szn_Races", "szn_Laps Led"], inplace=True)
pocono_stats_engineered.head()
# Out:
#             Driver  Avg Finish  Wins  Top 5's  DNF  Avg Rating  \
# 0    William Byron         9.4     0        3    0        96.7
# 1  Brad Keselowski        10.8     1       11    1        94.4
# 2     Denny Hamlin        11.3     7       16    3       108.7
# 3      Kyle Larson        11.6     0        5    0        95.8
# 4      Ryan Blaney        13.4     2        3    1        89.6
#
#    szn_Avg Finish  szn_Wins  szn_Top 5's  szn_Avg Rating  DNF_Prob  \
# 0            10.4         1            7           106.7  0.030000
# 1            24.3         0            1            62.9  0.037037
# 2            13.5         3            7            94.3  0.085714
# 3            12.8         3            9            96.0  0.030000
# 4            17.4         1            6            90.6  0.066667
#
#    track_Laps Led Per Race  szn_Laps Led Per Race  Std Dev
# 0                11.818182              48.062500      2.5
# 1                 9.148148               0.500000      2.5
# 2                24.514286              30.333333      2.5
# 3                 9.294118              53.187500      2.5
# 4                 6.333333              21.625000      3.5

# %%
# Input files able to be read from GitHub: Don't feel like doing the API request stuff to write this out as well,
# This is all behind the scenes anyways :)
# pocono_stats_engineered.to_csv("C:/Users/jakel/OneDrive/Desktop/GitHub/NASCAR-Race-Predictions/Data/Pocono-2025/pocono-sim-ready-data.csv")
